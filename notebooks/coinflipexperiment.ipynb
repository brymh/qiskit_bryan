# %% [markdown]
# # Coin Flip Experimenation and Learning Quantum intuition
#
# I hope to understand why we cant have an analogous classical system of a coin changing states to model the QC behavoirs and interactions although this currently doesnt make much intuitive sense to me
#
# I want to make a real life system that plays the coin game and mimics the choices the player and the CPU make and have the QC guess it accuratly

# %%
import qiskit

from qiskit import QuantumCircuit as qc
from qiskit.visualization import plot_bloch_multivector as qv
from qiskit.quantum_info import Statevector as sv
from IPython.display import display

def displayChanges (cir):
    s1 = sv.from_instruction(cir)
    qv(s1)
    display(qv(s1))
    

coin = qc(1) #init a quantum circuit with 1 qubit each time
coin1 = qc(1)

a = 0
b = 0

print ("before")

displayChanges(coin)
displayChanges(coin1)
coin1.h(0)
coin.x(0)
coin.h(0)


displayChanges(coin)
displayChanges(coin1)
# Out:
# before
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
